# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats

# %matplotlib inline

df = pd.read_csv('/Users/ananya/OneDrive - Personal/OneDrive/CodeDay-Labs-main/parkinsons.data')

# %%
#create heatmap
plt.figure(figsize=(16,16))
sb.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#counts null values in each column
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
#checks for duplicates rows
df.duplicated().value_counts()
# Out:
# False    195
# dtype: int64

# %%
#checks if status column has binary values
df['status'].unique()
# Out:
# array([1, 0])

# %%
#plotting data and outliers for MDVP:Fo(Hz)
df.boxplot(column = "MDVP:Fo(Hz)", figsize =(16,16))
# Out:
# <AxesSubplot:>

# %%
#plotting data and outliers for MDVP:Shimmer
df.boxplot(column = "MDVP:Shimmer", figsize =(16,16))
# Out:
# <AxesSubplot:>

# %%
#plotting data and outliers for NHR
df.boxplot(column = "NHR", figsize =(16,16))
# Out:
# <AxesSubplot:>

# %%
#scatter plot on status vs MDVP:Fo(Hz)
plt.figure(figsize=(16,16))
plt.scatter(df["status"], df["MDVP:Fo(Hz)"])
plt.title("Status vs MDVP:Fo(Hz)")
plt.xlabel("Status")
plt.ylabel("MDVP:Fo(Hz)")
plt.show()

# %%
#scatter plot on status vs MDVP:Shimmer
plt.figure(figsize=(16,16))
plt.scatter(df["status"], df["MDVP:Shimmer"])
plt.title("status vs MDVP:Shimmer")
plt.xlabel("status")
plt.ylabel("MDVP:Shimmer")
plt.show()

# %%
#scatter plot on status vs NHR
plt.figure(figsize = (16,16))
plt.scatter(df["status"], df["NHR"])
plt.title("status vs NHR")
plt.xlabel("status")
plt.ylabel("NHR")
plt.show()

# %%
#analysis of data
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...
